# %% [markdown]
# # Food Recognition
# **Capstone Project-2 Proposal | Image Recognition**
# **Project Title:** Food Recognition for Nutrition Tracking
# **Possible Usage:** Diet tracking, calorie estimation, and meal recommendations.
#
# 1. **Pizza**
# 2. **Burger**
# 3. **Salad**
# 4. **Sushi**
# 5. **Ice Cream**
# 6. **Pasta**
# 7. **Soup**
# 8. **Steak**
# 9. **Sandwich**
# 10. **Fries**
# 11. **Donut**
# 12. **Pancakes**
# 13. **Rice Dish**
# 14. **Taco**
# 15. **Fried Chicken**
# 16. **Hot Dog**
# 17. **Noodles**
# 18. **Curry**
# 19. **Dumplings**
# 20. **BBQ Ribs**
# 21. **Cheesecake**
# 22. **Waffles**
# 23. **Smoothie**
# 24. **Stew**
# 25. **Omelette**

# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 45.3 MB/s eta 0:00:00

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
# ...

# %%
# %cd /content/drive/My Drive/Work/Food_recognition

# %%
version = 1
img_path = 'test_item'
model_path = f'models/food-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1
#
# **Target:** Burger

# %%
img = Image.open(f'{img_path}/check_0.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/check_0.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('burger',
#  tensor(1),
#  tensor([5.7750e-07, 9.9992e-01, 1.3567e-08, 1.2205e-07, 3.3635e-07, 1.6300e-08,
#          1.0714e-07, 1.4030e-07, 3.3404e-06, 4.2053e-07, 3.6048e-07, 2.2313e-08,
#          4.6297e-08, 1.1721e-08, 5.0313e-06, 1.1523e-06, 1.9851e-07, 1.6867e-05,
#          1.1550e-08, 2.4117e-07, 1.5693e-08, 7.5787e-07, 4.9117e-05, 1.5008e-06,
#          2.6740e-08]))

# %% [markdown]
# # Inference 2
#
# **Target:** Pancake

# %%
img = Image.open(f'{img_path}/check_1.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/check_1.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('pancakes',
#  tensor(12),
#  tensor([1.3636e-06, 2.6930e-07, 1.1411e-06, 1.7847e-10, 7.6317e-06, 1.1701e-08,
#          7.2645e-09, 2.7138e-09, 4.3732e-08, 3.2800e-09, 1.0838e-10, 8.8419e-08,
#          9.9982e-01, 6.5316e-10, 1.5684e-10, 1.2318e-11, 3.1237e-09, 2.5267e-08,
#          3.1794e-08, 4.6924e-10, 8.3156e-07, 1.2589e-08, 8.4539e-08, 6.7639e-12,
#          1.6819e-04]))

# %% [markdown]
# # Inference 3
# **Target:** Ice Cream

# %%
img = Image.open(f'{img_path}/check_2.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/check_2.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('ice cream',
#  tensor(9),
#  tensor([3.9501e-10, 2.8595e-09, 2.1793e-02, 1.8778e-09, 1.4195e-06, 6.5701e-08,
#          3.7375e-08, 7.2096e-09, 9.5458e-09, 9.7803e-01, 3.7524e-09, 2.9299e-07,
#          3.5617e-06, 4.3664e-08, 2.0906e-07, 2.0612e-07, 1.2519e-04, 2.9325e-09,
#          4.6736e-05, 1.5971e-07, 1.5502e-09, 8.6087e-10, 8.0872e-08, 7.3881e-08,
#          2.4180e-06]))

# %% [markdown]
# # Inference 4
# **Target:** Steak

# %%
img = Image.open(f'{img_path}/check_3.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/check_3.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('steak',
#  tensor(20),
#  tensor([1.3098e-02, 3.2383e-04, 2.3599e-06, 5.2447e-06, 1.4747e-04, 2.5182e-05,
#          3.1881e-05, 9.6882e-06, 4.3261e-05, 8.0881e-05, 2.5743e-05, 7.6775e-06,
#          3.1254e-04, 3.7450e-06, 1.4711e-05, 2.6432e-05, 1.1257e-05, 7.0148e-05,
#          5.1670e-05, 1.2817e-05, 9.8539e-01, 6.0715e-05, 1.2688e-04, 5.5867e-06,
#          1.0998e-04]))

# %% [markdown]
# # Inference 5
# **Target:** Pasta

# %%
img = Image.open(f'{img_path}/check_4.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x83>

# %%
model.predict(f'{img_path}/check_4.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('pasta',
#  tensor(13),
#  tensor([2.0020e-05, 1.4401e-04, 1.0726e-05, 2.6947e-03, 4.7904e-05, 5.1799e-05,
#          2.0436e-04, 7.9785e-03, 3.5169e-04, 3.9764e-06, 5.6071e-02, 5.6839e-04,
#          8.0411e-05, 9.2074e-01, 4.9214e-05, 2.8936e-03, 2.0711e-03, 8.4937e-04,
#          8.4895e-05, 1.9551e-04, 1.0652e-04, 4.9814e-05, 8.5367e-05, 4.4999e-03,
#          1.4216e-04]))

# %% [markdown]
# # Inference 6
# **Target:** Curry

# %%
img = Image.open(f'{img_path}/check_5.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/check_5.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('curry',
#  tensor(3),
#  tensor([1.0698e-05, 9.3604e-06, 3.8152e-06, 9.6316e-01, 2.7975e-06, 2.2356e-04,
#          5.2374e-06, 8.6770e-06, 4.2505e-07, 2.5559e-06, 9.2154e-06, 1.6760e-05,
#          4.2350e-05, 1.7829e-05, 2.5335e-05, 4.0562e-05, 7.3823e-06, 3.8765e-06,
#          1.7724e-05, 3.5736e-03, 1.1051e-05, 3.2715e-02, 7.4972e-06, 5.8086e-05,
#          2.5233e-05]))

# %% [markdown]
# # Inference 7
# **Target:** Pizza

# %%
img = Image.open(f'{img_path}/check_6.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f'{img_path}/check_6.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('pizza',
#  tensor(14),
#  tensor([2.2605e-09, 3.5616e-09, 2.6338e-08, 4.2494e-09, 1.3204e-07, 9.0691e-10,
#          1.1553e-09, 4.9627e-09, 5.3148e-09, 4.5767e-11, 2.4167e-09, 1.3665e-06,
#          9.7744e-08, 3.0045e-08, 9.9999e-01, 2.7573e-08, 3.3752e-09, 3.5448e-08,
#          3.0475e-09, 9.7526e-09, 6.2084e-09, 1.4573e-09, 1.4957e-08, 2.6540e-06,
#          6.6580e-07]))
